# %% [markdown]
# # Preference Alignment with Direct Preference Optimization (DPO)
#
# This notebook will guide you through the process of fine-tuning a language model using Direct Preference Optimization (DPO). We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#      <h2 style='margin: 0;color:blue'>Exercise: Aligning SmolLM2 with DPOTrainer</h2>
#      <p>Take a dataset from the Hugging Face hub and align a model on it. </p>
#      <p><b>Difficulty Levels</b></p>
#      <p>🐢 Use the `trl-lib/ultrafeedback_binarized` dataset</p>
#      <p>🐕 Try out the `argilla/ultrafeedback-binarized-preferences` dataset</p>
#      <p>🦁 Select a dataset that relates to a real-world use case you’re interested in, or use the model you trained in
#         <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
# !uv pip install transformers datasets trl huggingface_hub --system
# Out:
# Using Python 3.11.11 environment at /usr
# Resolved 61 packages in 457ms
# ⠙ Preparing packages... (0/16)
# ⠙ Preparing packages... (0/16)
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# nvidia-cusolver-cu12 ------------------------------     0 B/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# nvidia-cusolver-cu12 ------------------------------ 14.82 KiB/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# nvidia-curand-cu12 ------------------------------     0 B/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 14.82 KiB/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 14.89 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 14.82 KiB/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 14.89 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 14.82 KiB/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 14.89 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 14.82 KiB/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------     0 B/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 14.89 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 14.82 KiB/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/140.16 KiB
# fsspec     ------------------------------ 16.00 KiB/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 14.89 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 14.82 KiB/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# multiprocess ------------------------------ 16.00 KiB/140.16 KiB
# fsspec     ------------------------------ 16.00 KiB/175.05 KiB
# xxhash     ------------------------------     0 B/190.26 KiB
# datasets   ------------------------------     0 B/469.38 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 14.89 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 14.82 KiB/122.01 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# multiprocess ------------------------------ 35.87 KiB/140.16 KiB
# fsspec     ------------------------------ 32.00 KiB/175.05 KiB
# xxhash     ------------------------------ 190.26 KiB/190.26 KiB
# trl        ------------------------------ 14.92 KiB/306.50 KiB
# datasets   ------------------------------ 108.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 32.00 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 63.98 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 495.34 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 588.68 KiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 30.89 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 30.82 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 500.41 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 428.08 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 48.00 KiB/346.60 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 58.05 KiB/140.16 KiB
# fsspec     ------------------------------ 48.00 KiB/175.05 KiB
# trl        ------------------------------ 30.92 KiB/306.50 KiB
# datasets   ------------------------------ 140.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 221.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 79.98 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 786.78 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 828.68 KiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 128.28 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 846.82 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 797.89 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 812.46 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 832.67 KiB/346.60 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------ 58.05 KiB/140.16 KiB
# fsspec     ------------------------------ 48.00 KiB/175.05 KiB
# trl        ------------------------------ 30.92 KiB/306.50 KiB
# datasets   ------------------------------ 140.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 221.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 95.98 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 863.34 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 828.68 KiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 128.28 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 846.82 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 863.28 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 876.46 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 927.02 KiB/346.60 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 79.04 KiB/140.16 KiB
# fsspec     ------------------------------ 76.30 KiB/175.05 KiB
# trl        ------------------------------ 62.92 KiB/306.50 KiB
# datasets   ------------------------------ 204.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 253.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 111.98 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.15 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.18 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 428.69 KiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.22 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.17 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.24 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.18 MiB/346.60 MiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 79.04 KiB/140.16 KiB
# fsspec     ------------------------------ 92.30 KiB/175.05 KiB
# trl        ------------------------------ 62.92 KiB/306.50 KiB
# datasets   ------------------------------ 220.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 285.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 127.87 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.65 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.71 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 1.71 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.72 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.53 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.73 MiB/346.60 MiB
# ⠹ Preparing packages... (1/16)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 127.04 KiB/140.16 KiB
# fsspec     ------------------------------ 108.30 KiB/175.05 KiB
# trl        ------------------------------ 78.92 KiB/306.50 KiB
# datasets   ------------------------------ 220.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 333.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 143.98 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.27 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.20 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 2.27 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.40 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.25 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.26 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.27 MiB/346.60 MiB
# ⠹ Preparing packages... (1/16)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------ 127.04 KiB/140.16 KiB
# fsspec     ------------------------------ 119.42 KiB/175.05 KiB
# trl        ------------------------------ 78.92 KiB/306.50 KiB
# datasets   ------------------------------ 236.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 365.04 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 171.92 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.94 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.89 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 2.91 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.99 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.95 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.94 MiB/346.60 MiB
# ⠹ Preparing packages... (1/16)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# multiprocess ------------------------------ 127.04 KiB/140.16 KiB
# fsspec     ------------------------------ 140.30 KiB/175.05 KiB
# trl        ------------------------------ 126.92 KiB/306.50 KiB
# datasets   ------------------------------ 252.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 477.99 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 171.92 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.64 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.42 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 3.69 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.67 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.59 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.44 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.62 MiB/346.60 MiB
# ⠹ Preparing packages... (1/16)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 156.30 KiB/175.05 KiB
# trl        ------------------------------ 158.92 KiB/306.50 KiB
# datasets   ------------------------------ 268.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 477.99 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.78 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.04 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.96 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 4.09 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.06 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.05 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.97 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.04 MiB/346.60 MiB
# ⠸ Preparing packages... (1/16)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 156.30 KiB/175.05 KiB
# trl        ------------------------------ 158.92 KiB/306.50 KiB
# datasets   ------------------------------ 268.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 493.99 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.54 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.69 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.48 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 4.68 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.69 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.62 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.42 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.45 MiB/346.60 MiB
# ⠸ Preparing packages... (1/16)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 172.08 KiB/175.05 KiB
# trl        ------------------------------ 174.92 KiB/306.50 KiB
# datasets   ------------------------------ 284.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 493.99 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.28 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.20 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.24 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 5.18 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.12 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.26 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.86 MiB/346.60 MiB
# ⠸ Preparing packages... (1/16)
# dill       ------------------------------ 113.53 KiB/113.53 KiB
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 172.08 KiB/175.05 KiB
# trl        ------------------------------ 184.37 KiB/306.50 KiB
# datasets   ------------------------------ 284.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 525.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.73 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.68 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.72 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 5.84 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.83 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.78 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.66 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# dill       ------------------------------ 113.53 KiB/113.53 KiB
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 172.08 KiB/175.05 KiB
# trl        ------------------------------ 200.37 KiB/306.50 KiB
# datasets   ------------------------------ 284.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 525.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.38 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.27 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.31 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 6.35 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.48 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.10 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.29 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# multiprocess ------------------------------ 140.16 KiB/140.16 KiB
# fsspec     ------------------------------ 172.08 KiB/175.05 KiB
# trl        ------------------------------ 200.37 KiB/306.50 KiB
# datasets   ------------------------------ 284.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 525.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.38 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.27 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.41 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 6.35 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.48 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.49 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.29 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# fsspec     ------------------------------ 172.08 KiB/175.05 KiB
# trl        ------------------------------ 200.37 KiB/306.50 KiB
# datasets   ------------------------------ 284.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 541.10 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.38 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.36 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.41 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 6.35 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.48 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.49 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.29 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# trl        ------------------------------ 222.92 KiB/306.50 KiB
# datasets   ------------------------------ 284.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 541.10 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.38 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.36 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.41 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 6.35 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.48 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.49 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.32 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.29 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# trl        ------------------------------ 238.92 KiB/306.50 KiB
# datasets   ------------------------------ 300.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 541.10 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.65 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.98 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.98 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 7.01 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.21 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 7.03 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.87 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.51 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# datasets   ------------------------------ 316.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 589.10 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.14 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.06 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 7.09 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 7.36 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.24 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 7.25 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.07 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.04 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# datasets   ------------------------------ 316.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 605.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.42 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.32 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 7.37 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 7.61 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.50 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 7.47 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.31 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.56 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# datasets   ------------------------------ 316.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 605.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.95 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.84 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.22 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.33 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.43 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.02 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.17 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.83 MiB/346.60 MiB
# ⠼ Preparing packages... (1/16)
# datasets   ------------------------------ 316.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 621.20 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 6.57 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.65 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.37 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 8.84 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 8.95 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.94 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 8.79 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.54 MiB/346.60 MiB
# ⠴ Preparing packages... (5/16)
# datasets   ------------------------------ 316.52 KiB/469.38 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 621.20 KiB/863.02 KiB
#  - fsspec==2024.10.0
#  + fsspec==2024.9.0
#  + multiprocess==0.70.16
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + trl==0.14.0
#  + xxhash==3.5.0

# %%
import os
from getpass import getpass
os.environ['HF_TOKEN'] = getpass()
# Out:
# ··········

# %% [markdown]
# ## Import libraries

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from trl import DPOTrainer, DPOConfig

# %% [markdown]
# ## Format dataset

# %%
dataset = load_dataset("maywell/ko_Ultrafeedback_binarized", token=os.environ['HF_TOKEN'])
# Out:
# (…)-00000-of-00001-dc7eba5173eb6ca1.parquet:   0%|          | 0.00/110M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/61966 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'chosen', 'rejected'],
#         num_rows: 61966
#     })
# })

# %%
def process_dataset(data):
    return {"prompt": [{"role": "user", "content": data["prompt"]}],
            "chosen": [{"role": "assistant", "content": data["chosen"]}],
            "rejected": [{"role": "assistant", "content": data["rejected"]}]}

train_ds = dataset.map(process_dataset)

# %%
train_ds["train"][0]
# Out:
# {'prompt': [{'content': '극단주의 및 폭력적 이데올로기를 확산하기 위해 소셜 미디어 플랫폼이 활용된 방식을 분석하고 예를 제시하는 1,000단어 분량의 오피니언 기고문을 공식적인 어조로 작성합니다. 분석에서 이러한 단체가 온라인에서 메시지를 전파하기 위해 사용하는 구체적인 전술과 이러한 전술이 개인과 사회에 미치는 영향에 대해 논의하세요. 또한 소셜 미디어에서 이러한 위험한 이데올로기의 확산을 막기 위해 시행할 수 있는 가능한 해결책을 제시하세요. 논거를 뒷받침할 수 있는 평판이 좋은 출처를 인용하여 잘 조사된 글이어야 합니다.',
#    'role': 'user'}],
#  'chosen': [{'content': '제목: 소셜 미디어와 극단주의의 독성 동맹: 인류의 진보에 대한 위협소셜 미디어 플랫폼의 등장은 우리가 정보를 공유하고 소비하는 방식에 영구적인 혁명을 가져왔습니다. 이러한 플랫폼은 전 세계 시청자에게 정보에 대한 접근성을 제공하고 개인이 지리적 장벽에 관계없이 연결할 수 있게 해주지만, 극단주의적이고 폭력적인 이데올로기의 확산의 배양지가 되어 인류의 진보에 심각한 위협이 되고 있습니다. 소셜 미디어의 확산과 이러한 플랫폼이 제공하는 익명성으로 인해 극단주의자들이 더 쉽게 자신의 메시지를 전파하고 신규 회원을 모집하며 표적 집단에 대한 폭력을 조장하여 치명적인 결과를 초래하고 있습니다.극단주의 단체는 종종 소셜 미디어의 바이럴 특성을 이용해 자신의 이데올로기를 전파합니다. 빠르게 진행되는 동영상, 눈에 띄는 슬로건, 정서적으로 충전된 콘텐츠는 이들이 사용하는 전략 중 일부입니다. 청중의 관심을 끌고 특히 공포, 분노, 증오를 불러일으키기 위해 빠르고 공격적인 전술을 사용합니다. 잘못된 정보와 음모론의 유포는 전통적인 미디어 소스에 대한 신뢰의 붕괴를 이용하여 극단주의적 이데올로기의 확산을 촉진합니다. 사용자에게 참여할 가능성이 높은 콘텐츠를 보여주도록 설계된 소셜 미디어 알고리즘은 실수로 더 극단적인 콘텐츠를 홍보하여 가시성을 더욱 악화시킬 수 있습니다.미얀마의 로힝야 위기는 소셜 미디어 홍보가 극단주의에 미치는 해로운 영향을 잘 보여주는 사례입니다. 2017년 페이스북 게시물에 허위 정보가 가득한 게시물은 무슬림 소수자인 로힝야족을 주로 불교를 믿는 나라에 위협으로 묘사했습니다. 이러한 게시물에는 종종 폭력적인 이미지와 피해자 비난 내러티브가 포함되어 실제 폭력, 난민, 대량 학살로 이어졌습니다. 유엔은 소셜 미디어가 로힝야족에 대한 적대감을 조성하는 데 "결정적인 역할"을 했다고 지적했습니다.극단주의 단체가 소셜 미디어에 미치는 영향은 즉각적으로 영향을 받는 지역의 피해자들 이상으로 확대될 수 있습니다. 온라인에서 극단주의 이데올로기가 확산되면 지리적 요인에 관계없이 누구에게나 영향을 미칠 수 있습니다. 개인은 소셜 미디어에 대한 극단주의 이데올로기에 취약한 개인이 있으며, 급변하는 세상에서 답과 의미를 찾으려고 노력하는 경우가 많습니다. 이러한 개인은 극단주의 단체가 제시하는 내러티브에 끌려들 수 있습니다. 이는 사회적 분열을 더욱 심화시키고 양극화를 증가시켜 생산적인 대화에 참여하고 사회 문제에 대한 해결책을 찾기가 어렵게 만듭니다.소셜 미디어에서 극단주의 이데올로기의 확산에 맞서기 위해서는 기술적 및 정책적 조치를 모두 통합하는 다각적인 접근이 필요합니다:1. 소셜 미디어 플랫폼의 책임: 이러한 플랫폼의 모니터링과 규제가 크게 강화되어야 합니다. 허위 뉴스, 혐오 발언, 폭력 선동을 막기 위해 엄격한 정책을 시행해야 합니다. 플랫폼은 사용자가 유해한 콘텐츠를 신고할 수 있는 쉬운 메커니즘을 제공하여 신속한 조치를 취할 수 있도록 해야 합니다.2. 교육과 인식: 개인은 소셜 미디어에서 극단주의 단체가 사용하는 전술을 인지해야 합니다. 이는 비판적 사고, 미디어 리터러시, 존중하는 담화 증진에 대해 가르치는 학교와 커뮤니티의 교육 이니셔티브를 통해 달성할 수 있습니다.3. 반대 내러티브: 극단주의적 내러티브에 도전하는 효과적인 반대 내러티브를 장려하고 이러한 플랫폼에서 공유해야 합니다. 여기에는 다양성, 회복력, 포용성에 대한 긍정적인 이야기를 공유하고, 세계 인류의 아름다움을 보여주며, 사실에 기반한 콘텐츠를 적극적으로 홍보하는 것이 포함될 수 있습니다.4. 협업: 정부, 시민사회단체, 기술대기업은 이 문제에 대응하기 위해 협력해야 합니다. 정부는 온라인에서 극단주의 이데올로기의 홍보를 막기 위한 법을 제정하고 시행해야 하며, 기술 대기업은 건전한 사회적 상호 작용과 사실적 정확성을 촉진하는 콘텐츠를 우선시하는 보다 효과적인 알고리즘을 설계하기 위해 투자해야 합니다.5. 기술을 극단주의에 맞서게 한다: 인공 지능과 머신 러닝 기술을 사용하면 유해한 콘텐츠를 탐지하고 제거하는 데 도움이 될 수 있습니다. 이러한 시스템은 온라인 담화의 패턴을 분석하고, 검토할 만한 콘텐츠를 플래그하고, 폭력적인 행동으로 확대되기 전에 극단적인 행동을 예측할 수 있습니다.',
#    'role': 'assistant'}],
#  'rejected': [{'content': '**소셜 미디어에서 극단주의 및 폭력적 이데올로기의 확산**소셜 미디어 플랫폼은 극단주의 및 폭력적 이데올로기를 확산하는 강력한 도구가 되었습니다. 이러한 플랫폼은 극단주의자들이 같은 생각을 가진 사람들과 연결하고, 더 많은 청중에게 메시지를 전파하고, 새로운 회원을 모집할 수 있는 방법을 제공합니다.극단주의자들은 다양한 방식으로 소셜 미디어를 사용하여 메시지를 전파합니다. 한 가지 일반적인 전술은 청소년에게 어필할 수 있도록 고안된 콘텐츠를 제작하고 공유하는 것입니다. 이러한 콘텐츠는 종종 재미있거나 충격적이거나 도발적인 밈, 동영상 및 이미지의 형태를 취합니다. 극단주의자들은 또한 소셜 미디어를 사용하여 도전이나 비판을 받지 않고 메시지를 공유할 수 있는 에코 챔버를 만듭니다. 이는 사람들이 극단주의 이데올로기의 인력에서 벗어나기 어렵게 만들 수 있습니다.소셜 미디어에서 극단주의 및 폭력적 이데올로기가 확산되면 여러 가지 부정적인 영향을 미칠 수 있습니다. 이러한 이데올로기는 온라인과 오프라인 모두에서 폭력으로 이어질 수 있습니다. 또한 사람들이 평화롭게 함께 살기 어렵게 만들 수도 있습니다. 또한 민주주의와 법치를 훼손할 수 있습니다.소셜 미디어에서 극단주의 및 폭력적 이데올로기의 확산에 대응하기 위해 취할 수 있는 조치는 여러 가지가 있습니다. 중요한 한 가지 단계는 이러한 이데올로기의 위험성에 대해 사람들을 교육하는 것입니다. 이러한 교육은 학교, 가정, 커뮤니티에서 이루어질 수 있습니다. 또한 소셜 미디어 플랫폼에서 극단주의 콘텐츠를 식별하고 제거하는 데 도움이 되는 도구를 개발하는 것도 중요합니다. 또한 혐오와 차별을 용납하지 않는 보다 포용적인 사회를 구축하기 위해 노력하는 것도 중요합니다.소셜 미디어에서 극단주의 및 폭력적 이데올로기가 확산되는 것은 심각한 문제입니다. 하지만 이 문제를 해결하기 위해 취할 수 있는 조치는 여러 가지가 있습니다. 이러한 이데올로기의 위험성에 대해 사람들을 교육하고, 극단주의 콘텐츠를 제거하는 도구를 개발하고, 보다 포용적인 사회를 구축하기 위해 노력함으로써 이러한 위험한 아이디어의 확산을 막는 데 도움을 줄 수 있습니다.전략적 대화 연구소의 연구에 따르면 2017년 트위터에 활성 테러리스트 계정이 10만 개가 넘었습니다. 이러한 계정은 선전을 퍼뜨리고, 신규 회원을 모집하고, 폭력을 조장하는 데 사용되었습니다. 이 연구에 따르면 극단주의자들이 소셜 미디어를 사용하는 것이 최근 몇 년 동안 증가하고 있는 것으로 나타났습니다.극단주의자들이 소셜 미디어를 사용하는 가장 효과적인 방법 중 하나는 청소년에게 어필할 수 있도록 고안된 콘텐츠를 제작하고 공유하는 것입니다. 이러한 콘텐츠는 종종 재미있거나 충격적이거나 도발적인 밈, 동영상 및 이미지의 형태를 취합니다. 극단주의자들은 이 콘텐츠를 사용하여 관심을 끌고 청소년들과 대화를 시작합니다. 청소년과 교류한 후에는 이들을 자신의 이데올로기에 대한 독화로 만들기 시작할 수 있습니다.극단주의자들은 또한 소셜 미디어를 사용하여 도전이나 비판을 받지 않고 메시지를 공유할 수 있는 에코 챔버를 만듭니다. 이는 사람들이 극단주의 이데올로기의 인력에서 벗어나기 어렵게 만들 수 있습니다. 이러한 에코 챔버에서 극단주의자들은 서로를 급진화시키고 공격을 계획하고 실행할 수 있습니다.소셜 미디어에서 극단주의 및 폭력적 이데올로기가 확산되면 여러 가지 부정적인 영향을 미칠 수 있습니다. 이러한 이데올로기는 온라인과 오프라인 모두에서 폭력으로 이어질 수 있습니다. 또한 사람들이 평화롭게 함께 살기 어렵게 만들 수 있습니다. 또한 민주주의와 법치를 훼손할 수 있습니다.소셜 미디어에서 극단주의 및 폭력적 이데올로기의 확산에 대응하기 위해 취할 수 있는 조치는 여러 가지가 있습니다. 중요한 한 가지 단계는 이러한 이데올로기의 위험성에 대해 사람들을 교육하는 것입니다. 이러한 교육은 학교, 가정, 커뮤니티에서 이루어질 수 있습니다. 또한 소셜 미디어 플랫폼에서 극단주의 콘텐츠를 식별하고 제거하는 데 도움이 되는 도구를 개발하는 것도 중요합니다. 또한 혐오와 차별을 용납하지 않는 보다 포용적인 사회를 구축하기 위해 노력하는 것도 중요합니다.소셜 미디어에서 극단주의 및 폭력적 이데올로기가 확산되는 것은 심각한 문제입니다. 하지만 이 문제를 해결하기 위해 취할 수 있는 조치는 여러 가지가 있습니다. 이러한 이데올로기의 위험성에 대해 사람들을 교육하고, 극단주의 콘텐츠를 제거하는 도구를 개발하고, 보다 포용적인 사회를 구축하기 위해 노력함으로써 이러한 위험한 아이디어의 확산을 막는 데 도움을 줄 수 있습니다.',
#    'role': 'assistant'}]}

# %%
# TODO: 🐕 If your dataset is not represented as conversation lists, you can use the `process_dataset` function to convert it.

# %% [markdown]
# ## Select the model
#
# We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; width:80%; color:black'>
#      <p>🦁 change the model to the path or repo id of the model you trained in <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
from trl import DPOConfig, DPOTrainer
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
model = AutoModelForCausalLM.from_pretrained("josang1204/Qweb2.5-FT-CSY", token=os.environ['HF_TOKEN'])
tokenizer = AutoTokenizer.from_pretrained("josang1204/Qweb2.5-FT-CSY", token=os.environ['HF_TOKEN'])
# Out:
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.26k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/616 [00:00<?, ?B/s]

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)

model = model.to(device)
model.config.use_cache = False
finetune_name = "Qweb2.5-FT-DPO-CSY"
finetune_tags = ["smol-course", "module_2"]

# %% [markdown]
# ## Train model with DPO

# %%
# Training arguments
training_args = DPOConfig(
    # Training batch size per GPU
    per_device_train_batch_size=4,
    # Number of updates steps to accumulate before performing a backward/update pass
    # Effective batch size = per_device_train_batch_size * gradient_accumulation_steps
    gradient_accumulation_steps=4,
    # Saves memory by not storing activations during forward pass
    # Instead recomputes them during backward pass
    gradient_checkpointing=True,
    # Base learning rate for training
    learning_rate=5e-5,
    # Learning rate schedule - 'cosine' gradually decreases LR following cosine curve
    lr_scheduler_type="cosine",
    # Total number of training steps
    max_steps=100,
    # Disables model checkpointing during training
    save_strategy="no",
    # How often to log training metrics
    logging_steps=1,
    # Directory to save model outputs
    output_dir="qwen_csy_dpo_output",
    # Number of steps for learning rate warmup
    warmup_steps=100,
    # Use bfloat16 precision for faster training
    bf16=True,
    # Disable wandb/tensorboard logging
    report_to="none",
    # Keep all columns in dataset even if not used
    remove_unused_columns=False,
    # Enable MPS (Metal Performance Shaders) for Mac devices
    # use_mps_device=device == "mps",
    # Model ID for HuggingFace Hub uploads
    hub_model_id=finetune_name,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    beta=0.1,
    # Maximum length of the input prompt in tokens
    max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    max_length=1536,
)

# %%
trainer = DPOTrainer(
    # The model to be trained
    model=model,
    # Training configuration from above
    args=training_args,
    # Dataset containing preferred/rejected response pairs
    train_dataset=dataset["train"],
    # Tokenizer for processing inputs
    processing_class=tokenizer,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    # beta=0.1,
    # Maximum length of the input prompt in tokens
    # max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    # max_length=1536,
)
# Out:
# Applying chat template to train dataset:   0%|          | 0/61966 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/61966 [00:00<?, ? examples/s]

# %%
# Train the model
trainer.train()

# Save the model
trainer.save_model(f"./{finetune_name}")

# Save to the huggingface hub if login (HF_TOKEN is set)
# Out:
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       
#       <td>5.218000</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>2.362900</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>3.245400</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>2.320100</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.439600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>3.546900</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.522300</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>2.105900</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>2.810800</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.444300</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>2.911600</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>2.313700</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>12.883700</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.734400</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.426400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.583500</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-21-3e6fa80674a3> in <cell line: 0>()
#       7 # Save to the huggingface hub if login (HF_TOKEN is set)
#       8 if os.getenv("HF_TOKEN"):
# ----> 9     trainer.push_to_hub(tags=finetune_tags)
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in push_to_hub(self, commit_message, blocking, token, revision, **kwargs)
#    4729         # In case the user calls this method with args.push_to_hub = False
#    4730         if self.hub_model_id is None:
# -> 4731             self.init_hf_repo(token=token)
#    4732
#    4733         # Needs to be executed on all processes for TPU training, but will only save on the processed determined by
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in init_hf_repo(self, token)
#    4541
#    4542         token = token if token is not None else self.args.hub_token
# -> 4543         repo_url = create_repo(repo_name, token=token, private=self.args.hub_private_repo, exist_ok=True)
#    4544         self.hub_model_id = repo_url.repo_id
#    4545         self.push_in_progress = None
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in create_repo(self, repo_id, token, private, repo_type, exist_ok, resource_group_id, space_sdk, space_hardware, space_storage, space_sleep_time, space_secrets, space_variables)
#    3479
#    3480         try:
# -> 3481             hf_raise_for_status(r)
#    3482         except HTTPError as err:
#    3483             if exist_ok and err.response.status_code == 409:
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     475         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     476         # as well (request id and/or server error message)
# --> 477         raise _format(HfHubHTTPError, str(e), response) from e
#     478
#     479
#
# HfHubHTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/repos/create (Request ID: Root=1-67a893e7-1bc46fc42da7e1e663a01648;fb206d09-3924-4289-8d2a-6d471a7f3a59)
#
# Invalid credentials in Authorization header

# %%
trainer.push_to_hub(tags=finetune_tags, token=os.environ["HF_TOKEN"])
# Out:
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/6.20k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/josang1204/Qweb2.5-FT-DPO-CSY/commit/a289d7ec7c82cfe7f3c226227dfffaa335a36712', commit_message='End of training', commit_description='', oid='a289d7ec7c82cfe7f3c226227dfffaa335a36712', pr_url=None, repo_url=RepoUrl('https://huggingface.co/josang1204/Qweb2.5-FT-DPO-CSY', endpoint='https://huggingface.co', repo_type='model', repo_id='josang1204/Qweb2.5-FT-DPO-CSY'), pr_revision=None, pr_num=None)

# %%
model
# Out:
# Qwen2ForCausalLM(
#   (model): Qwen2Model(
#     (embed_tokens): Embedding(151936, 896)
#     (layers): ModuleList(
#       (0-23): 24 x Qwen2DecoderLayer(
#         (self_attn): Qwen2Attention(
#           (q_proj): Linear(in_features=896, out_features=896, bias=True)
#           (k_proj): Linear(in_features=896, out_features=128, bias=True)
#           (v_proj): Linear(in_features=896, out_features=128, bias=True)
#           (o_proj): Linear(in_features=896, out_features=896, bias=False)
#         )
#         (mlp): Qwen2MLP(
#           (gate_proj): Linear(in_features=896, out_features=4864, bias=False)
#           (up_proj): Linear(in_features=896, out_features=4864, bias=False)
#           (down_proj): Linear(in_features=4864, out_features=896, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): Qwen2RMSNorm((896,), eps=1e-06)
#         (post_attention_layernorm): Qwen2RMSNorm((896,), eps=1e-06)
#       )
#     )
#     (norm): Qwen2RMSNorm((896,), eps=1e-06)
#     (rotary_emb): Qwen2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=896, out_features=151936, bias=False)
# )

# %% [markdown]
# ## 💐 You're done!
#
# This notebook provided a step-by-step guide to fine-tuning the `HuggingFaceTB/SmolLM2-135M` model using the `DPOTrainer`. By following these steps, you can adapt the model to perform specific tasks more effectively. If you want to carry on working on this course, here are steps you could try out:
#
# - Try this notebook on a harder difficulty
# - Review a colleagues PR
# - Improve the course material via an Issue or PR.
